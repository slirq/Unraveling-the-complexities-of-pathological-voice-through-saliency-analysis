# %%
import pandas as pd
from statistics import mean, stdev
import matplotlib.pyplot as plt
# Out:
# C:\Users\abdul\AppData\Roaming\Python\Python37\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.8' currently installed).
#   warnings.warn(msg, UserWarning)

# %%
names[i].split('.')[0]
print('./IMG/feat/jpg/acc_'+(names[i].split('.')[0])+'.png')
# Out:
# ./IMG/feat/jpg/acc_track_curve_MFCC.png

# %%
for i in range(3):
    df = pd.read_csv(names[i])
    plt.title(tit[i],fontsize = 20)
    plt.plot(df['accuracy'][:ep[i]],color = 'red')
    plt.ylabel("Test Accuracy",fontsize = 20)
    plt.xlabel("Epochs",fontsize = 20)
    plt.xticks(rotation=0, fontsize=20)
    plt.yticks(rotation=0, fontsize=20)
    plt.show()
    
#     plt.savefig('./IMG/feat/jpg/acc_'+(names[i].split('.')[0])+'.png',bbox_inches='tight',dpi=100)
#     plt.savefig('./IMG/feat/eps/acc_'+(names[i].split('.')[0])+'.eps',bbox_inches='tight',dpi=100)
    
    plt.plot(df['loss'][:ep[i]],color = 'Blue')
    plt.ylabel("Test Loss",fontsize = 20)
    plt.xlabel("Epochs",fontsize = 20)
    plt.xticks(rotation=0, fontsize=20)
    plt.yticks(rotation=0, fontsize=20)
    plt.show()
    
#     plt.savefig('./IMG/feat/jpg/loss_'+(names[i].split('.')[0])+'.png',bbox_inches='tight',dpi=100)
#     plt.savefig('./IMG/feat/eps/loss_'+(names[i].split('.')[0])+'.eps',bbox_inches='tight',dpi=100)
#     print(names[i].split('.')[0],stdev(df['accuracy'][:ep[i]]),stdev(df['sensitivity'][:ep[i]]))

# %%
names = ["track_curve_MLP.csv","track_curve_1D.csv","track_curve_MFCC.csv"]
ep = [5000,500,500]
tit=['MLP OpenSmile model', 'STFT model','MFCC model',]
L,W=10,20

fig, axs = plt.subplots(2,3, figsize=(W, L))

for i in range(3):
    df = pd.read_csv(names[i])
    axs[0,i].plot(df['accuracy'][:ep[i]],color = 'red')
    axs[1,i].plot(df['loss'][:ep[i]],color = 'blue')
    print(tit[i],np.std(df['accuracy'][:ep[i]]),np.std(df['loss'][:ep[i]]))
    axs[0,i].set_title(tit[i],fontsize=20)
    plt.xticks(rotation=0, fontsize=20)
    axs[0,i].tick_params(labelsize=15)
    axs[1,i].tick_params(labelsize=15)
    
vow = ['(A)','(B)','(C)','(D)','(E)','(F)']
val=['Test Accuacy','Test Loss',"",'']
[axs[i, 0].set_ylabel(val[i],fontsize=20) for i in range(2)]
[axs[0, i].set_xlabel(vow[i],fontsize=20) for i in range(3)]
[axs[1, i].set_xlabel(vow[i+3]+'\nEpochs',fontsize=20) for i in range(3)]



# fig.legend(handles=[a, b],loc='lower center',fontsize=15,ncol=2)
fig.savefig(f'./IMG/stft/jpg/TRAIN_TEST_GRAPH.png',bbox_inches='tight',dpi=200)
fig.savefig(f'./IMG/stft/eps/TRAIN_TEST_GRAPH.eps',bbox_inches='tight',dpi=200)
# #     193 242
# Out:
# MLP OpenSmile model 0.07911858756007226 0.523220146587736
# STFT model 0.047522685192621976 0.12418193226607936
# MFCC model 0.057923316780227024 0.12651592348258828

# %%
df2 = pd.read_csv("track_curve_MFCC.csv")

plt.plot(df2['accuracy'])
plt.show()

plt.plot(df2['loss'])
plt.show()

# %%
df3 = pd.read_csv("track_curve_MLP.csv")
plt.plot(df3['accuracy'])
plt.show()

plt.plot(df3['loss'])
plt.show()

# %%
plt.plot(df3['accuracy'])
plt.plot(df2['accuracy'])
plt.plot(df1['accuracy'])
plt.show()

# %%
plt.plot(df3['loss'])
plt.plot(df2['loss'])
plt.plot(df1['loss'])
plt.show()

# %%
# from statistics import mean, stdev
# f = open("std_new_mfcc_model.csv", 'r')

# # Remove the first line City,Job,Salary
# f.readline()

# # Create the list of salaries 
# salaries = []

# for line in f.readlines():
#   # After splitting the line, take the last element, remove extra spaces and cast it to int.
#   value = int(line.split(',')[-1].strip())
#   # Add the value to the salaries list.
#   salaries.append(value)

# # min and max return the minimum and the maximum value of the list.
# print min(salaries), max(salaries)   
# print mean(salaries), stdev(salaries)  
# f.close()

# %%
import pandas as pd
from statistics import mean, stdev
import matplotlib.pyplot as plt

names = ["std_new_mfcc_model.csv","std_new_opensmile_model.csv","std_new_stft_model_2.csv"]
ep = [500,5000,500]
tit=['MFCC model','MLP OpenSmile model', 'STFT model']
for i in range(3):
    df = pd.read_csv(names[i])
    plt.title(tit[i])
    plt.plot(df['accuracy'][:ep[i]],color = 'red')
    plt.ylabel("Test Accuracy")
    plt.xlabel("Epochs")
    plt.show()
    
#     plt.savefig(f'./IMG/feat/jpg/{names[i].split('.')[0]}.png',bbox_inches='tight',dpi=100)
#     plt.savefig(f'./IMG/feat/eps/{names[i].split('.')[0]}.eps',bbox_inches='tight',dpi=100)
    print(names[i].split('.')[0],stdev(df['accuracy'][:ep[i]]),stdev(df['sensitivity'][:ep[i]]))

# df = pd.read_csv()
# plt.plot(df['accuracy'])
# plt.show()
# print("std_new_opensmile_model.csv",stdev(df['accuracy']),stdev(df['sensitivity']))

# df = pd.read_csv()
# plt.plot(df['accuracy'])
# plt.show()
# print("std_new_stft_model",stdev(df['accuracy']),stdev(df['sensitivity']))
# Out:
# std_new_mfcc_model 0.05561818599269676 0.017811980113225344
# std_new_opensmile_model 0.07997403405571626 0.035944604678099686
# std_new_stft_model_2 0.053921237284153115 0.01890043242724302

# %%
# len(df['accuracy'])
# Out:
# 946
